# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Sai Prathyusha Malla, Data Analyst

# %% [markdown]
# <i> I love the insights you can derive from visualising data in different forms. That's why I am studying data science. <i>

# %% [markdown]
# ### The following code will add two numbers

# %%
def sum(a, b):
    return a+b

sum(2, 3)
# Out:
# 5

# %% [markdown]
# In this cell, I am including many elements. The first element is a horizontal rule:
# <hr />
#
# - Then we have a bulleted list
# - With more bullet points and,
#     - sub bullet points
# 1. Similarly, we also have numbered lists
# 2. With more numbers
# <hr />
# Here is how a table would look like:
#
# | Type | Example |
# |----|----|
# | URL | [Wikipedia](https://www.wikipedia.org/)|
